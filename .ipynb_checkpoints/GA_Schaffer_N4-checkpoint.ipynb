# %% [markdown]
# pygad>=2.19.0
# numpy>=1.24.0
# matplotlib>=3.7.0
# seaborn>=0.12.2
# plotly>=5.14.0
# opencv-python>=4.7.0

# %%
pip install -r requirements.txt

# %% [markdown]
# 1. Funções auxiliares e definições

# %%
import numpy as np
import pandas as pd
import pygad
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.graph_objects as go
import cv2
import os

os.makedirs("logs", exist_ok=True)

# Domínio da função
x_min, x_max = -100, 100
y_min, y_max = -100, 100
precision = 5
n_bits = 25
genome_length = 2 * n_bits  # x + y

# GA config
POP_SIZE = 500
N_GEN = 500
N_RUNS = 32
CROSSOVER_RATE = 0.8
MUTATION_RATE = 0.01
SAVE_INTERVAL = 10  # Intervalo de frames para o GIF

# Função Shaffer F6
def shaffer_f6(x, y):
    num = np.sin(np.sqrt(x**2 + y**2))**2 - 0.5
    denom = (1 + 0.001 * (x**2 + y**2))**2
    return 0.5 - num / denom

# Conversão binária → float
def binary_to_float(binary_array, domain_min, domain_max):
    integer_value = int("".join(str(int(b)) for b in binary_array), 2)
    scale = (domain_max - domain_min) / (2**len(binary_array) - 1)
    return domain_min + integer_value * scale

# Decodificar cromossomo
def decode_solution(solution):
    x_bin = solution[:n_bits]
    y_bin = solution[n_bits:]
    x = binary_to_float(x_bin, x_min, x_max)
    y = binary_to_float(y_bin, y_min, y_max)
    return x, y

# %% [markdown]
# 2. Execução do algoritmo genético com pygad

# %%
# Fitness function para o pygad
def fitness_func(ga_instance, solution, solution_idx):
    x, y = decode_solution(solution)
    return shaffer_f6(x, y)

# Espaço dos genes (binário)
gene_space = [0, 1]

# Armazenar resultados
# Armazenar resultados
all_runs_fitness = []
best_attempt = {}

for run in range(N_RUNS):
    print(f"\n🧪 Iniciando Execução {run+1}/{N_RUNS}")
    generation_logs = []
    run_start = time.time()

    def on_generation(ga_instance):
        gen = ga_instance.generations_completed
        if gen % 50 == 0 or gen == 1:
            fitness_values = ga_instance.last_generation_fitness
            min_fit = np.min(fitness_values)
            mean_fit = np.mean(fitness_values)
            max_fit = np.max(fitness_values)

            # Registrar no CSV
            generation_logs.append({
                "run": run + 1,
                "generation": gen,
                "min_fitness": min_fit,
                "mean_fitness": mean_fit,
                "max_fitness": max_fit
            })

            # Print no terminal
            print(f" Geração {gen:03}: min={min_fit:.5f}, média={mean_fit:.5f}, max={max_fit:.5f}")

    ga = pygad.GA(
        num_generations=N_GEN,
        num_parents_mating=int(POP_SIZE * CROSSOVER_RATE),
        fitness_func=fitness_func,
        sol_per_pop=POP_SIZE,
        num_genes=genome_length,
        gene_space=gene_space,
        parent_selection_type="rws",
        crossover_type="single_point",
        mutation_type="random",
        mutation_percent_genes=int(MUTATION_RATE * 100),
        keep_elitism=1,
        on_generation=on_generation,
        save_best_solutions=True
    )

    ga.run()
    fitness_history = ga.best_solutions_fitness
    all_runs_fitness.append(fitness_history)

    # Atualizar melhor tentativa
    if not best_attempt or max(fitness_history) > max(best_attempt["fitness"]):
        best_attempt = {
            "ga": ga,
            "fitness": fitness_history
        }
    
    # Tempo de execução da rodada
    run_time = time.time() - run_start
    total_time = time.time() - global_start

    # Log de tempo
    print(f"⏱️ Tempo da execução {run+1}: {run_time:.2f} segundos")
    print(f"⏳ Tempo acumulado: {total_time:.2f} segundos")
    print(f"✅ Finalizada Execução {run+1}/{N_RUNS} — Melhor fitness: {max(fitness_history):.5f}")

    # Adiciona tempo ao log
    for row in generation_logs:
        row["run_time_seconds"] = run_time
        row["total_time_seconds"] = total_time

    # Salvar CSV da execução atual
    df = pd.DataFrame(generation_logs)
    df.to_csv(f"logs/execucao_{run+1:02}.csv", index=False)

    print(f"✅ Finalizada Execução {run+1}/{N_RUNS} — Melhor fitness: {max(fitness_history):.5f}")
# Out:
# 🧪 Iniciando Execução 1/32
#  Geração 001: min=0.20532, média=0.50642, max=0.92126
# /home/phvguimaraes/miniconda3/envs/rs-env/lib/python3.11/site-packages/pygad/pygad.py:1136: UserWarning: Use the 'save_best_solutions' parameter with caution as it may cause memory overflow when either the number of generations or number of genes is large.
#   warnings.warn("Use the 'save_best_solutions' parameter with caution as it may cause memory overflow when either the number of generations or number of genes is large.")
#  Geração 050: min=0.04579, média=0.53500, max=0.99028
#  Geração 100: min=0.00479, média=0.61308, max=0.99028
#  Geração 150: min=0.00279, média=0.61907, max=0.99028
#  Geração 200: min=0.00849, média=0.67677, max=0.99028
#  Geração 250: min=0.01935, média=0.66318, max=0.99028
#  Geração 300: min=0.00290, média=0.63562, max=0.99028
#  Geração 350: min=0.02231, média=0.60932, max=0.99028
#  Geração 400: min=0.02742, média=0.61587, max=0.99028
#  Geração 450: min=0.02148, média=0.62339, max=1.00000
#  Geração 500: min=0.00588, média=0.66441, max=1.00000
# ✅ Finalizada Execução 1/32 — Melhor fitness: 1.00000
#
# 🧪 Iniciando Execução 2/32
#  Geração 001: min=0.07895, média=0.50157, max=0.91198
#  Geração 050: min=0.04528, média=0.53397, max=0.99984
#  Geração 100: min=0.03569, média=0.61082, max=0.99999
#  Geração 150: min=0.00366, média=0.65757, max=1.00000
#  Geração 200: min=0.02625, média=0.61645, max=1.00000
#  Geração 250: min=0.02267, média=0.63289, max=1.00000
#  Geração 300: min=0.03258, média=0.65400, max=1.00000
#  Geração 350: min=0.00258, média=0.63130, max=1.00000
#  Geração 400: min=0.02399, média=0.65927, max=1.00000
#  Geração 450: min=0.00268, média=0.60919, max=1.00000
#  Geração 500: min=0.06493, média=0.66401, max=1.00000
# ✅ Finalizada Execução 2/32 — Melhor fitness: 1.00000
#
# 🧪 Iniciando Execução 3/32
#  Geração 001: min=0.05711, média=0.50071, max=0.82178
#  Geração 050: min=0.02254, média=0.56421, max=0.99028
#  Geração 100: min=0.02207, média=0.64581, max=0.99028
#  Geração 150: min=0.02498, média=0.67119, max=0.99028
#  Geração 200: min=0.05883, média=0.62787, max=0.99028
#  Geração 250: min=0.03134, média=0.64399, max=0.99028
#  Geração 300: min=0.05856, média=0.64717, max=0.99028
#  Geração 350: min=0.05753, média=0.67555, max=0.99028
#  Geração 400: min=0.00592, média=0.68627, max=0.99028
#  Geração 450: min=0.02147, média=0.65924, max=0.99028
#  Geração 500: min=0.03079, média=0.68094, max=0.99028
# ✅ Finalizada Execução 3/32 — Melhor fitness: 0.99028
#
# 🧪 Iniciando Execução 4/32
#  Geração 001: min=0.17079, média=0.50618, max=0.96164
#  Geração 050: min=0.09038, média=0.56962, max=0.99028
#  Geração 100: min=0.04118, média=0.56955, max=1.00000
#  Geração 150: min=0.00248, média=0.57810, max=1.00000
#  Geração 200: min=0.00461, média=0.57054, max=1.00000
#  Geração 250: min=0.02240, média=0.66591, max=1.00000
#  Geração 300: min=0.04843, média=0.64467, max=1.00000
#  Geração 350: min=0.03072, média=0.62638, max=1.00000
#  Geração 400: min=0.00247, média=0.63989, max=1.00000
#  Geração 450: min=0.02738, média=0.65860, max=1.00000
#  Geração 500: min=0.02155, média=0.65091, max=1.00000
# ✅ Finalizada Execução 4/32 — Melhor fitness: 1.00000
#
# 🧪 Iniciando Execução 5/32
#  Geração 001: min=0.15278, média=0.50492, max=0.97770
#  Geração 050: min=0.02965, média=0.53060, max=0.99908
#  Geração 100: min=0.01134, média=0.55901, max=1.00000
#  Geração 150: min=0.00551, média=0.59618, max=1.00000
#  Geração 200: min=0.04646, média=0.58941, max=1.00000
#  Geração 250: min=0.02172, média=0.62349, max=1.00000
#  Geração 300: min=0.00998, média=0.62891, max=1.00000
#  Geração 350: min=0.01062, média=0.62378, max=1.00000
#  Geração 400: min=0.00627, média=0.63882, max=1.00000
#  Geração 450: min=0.00246, média=0.61171, max=1.00000
#  Geração 500: min=0.00250, média=0.64162, max=1.00000
# ✅ Finalizada Execução 5/32 — Melhor fitness: 1.00000
#
# 🧪 Iniciando Execução 6/32
#  Geração 001: min=0.07581, média=0.49790, max=0.88860
#  Geração 050: min=0.03148, média=0.53712, max=0.99028
#  Geração 100: min=0.05628, média=0.50960, max=0.99028
#  Geração 150: min=0.09328, média=0.51992, max=0.99028
#  Geração 200: min=0.00364, média=0.64151, max=0.99028
#  Geração 250: min=0.06041, média=0.65372, max=0.99028
#  Geração 300: min=0.05765, média=0.62640, max=0.99028
#  Geração 350: min=0.03967, média=0.65191, max=0.99028
#  Geração 400: min=0.02882, média=0.66880, max=0.99028
#  Geração 450: min=0.02314, média=0.64315, max=0.99028
#  Geração 500: min=0.06071, média=0.65751, max=0.99028
# ✅ Finalizada Execução 6/32 — Melhor fitness: 0.99028
#
# 🧪 Iniciando Execução 7/32
#  Geração 001: min=0.12535, média=0.50134, max=0.96892
#  Geração 050: min=0.06305, média=0.52440, max=0.99028
#  Geração 100: min=0.02429, média=0.62729, max=0.99955
#  Geração 150: min=0.03083, média=0.65197, max=1.00000
#  Geração 200: min=0.02205, média=0.66823, max=1.00000
#  Geração 250: min=0.04288, média=0.67313, max=1.00000
#  Geração 300: min=0.02850, média=0.60865, max=1.00000
#  Geração 350: min=0.05588, média=0.67055, max=1.00000
#  Geração 400: min=0.06656, média=0.65005, max=1.00000
#  Geração 450: min=0.00328, média=0.65121, max=1.00000
#  Geração 500: min=0.01970, média=0.66274, max=1.00000
# ✅ Finalizada Execução 7/32 — Melhor fitness: 1.00000
#
# 🧪 Iniciando Execução 8/32
#  Geração 001: min=0.23526, média=0.50035, max=0.80912
#  Geração 050: min=0.02992, média=0.56054, max=0.99028
#  Geração 100: min=0.00905, média=0.62674, max=0.99028
#  Geração 150: min=0.02788, média=0.64292, max=0.99028
#  Geração 200: min=0.06420, média=0.65964, max=0.99028
#  Geração 250: min=0.02162, média=0.66768, max=0.99028
#  Geração 300: min=0.03948, média=0.66163, max=0.99028
#  Geração 350: min=0.05649, média=0.67340, max=0.99028
#  Geração 400: min=0.03306, média=0.61973, max=0.99028
#  Geração 450: min=0.01495, média=0.61535, max=0.99028
#  Geração 500: min=0.02154, média=0.65344, max=0.99028
# ✅ Finalizada Execução 8/32 — Melhor fitness: 0.99028
#
# 🧪 Iniciando Execução 9/32
#  Geração 001: min=0.10575, média=0.50094, max=0.86991
#  Geração 050: min=0.02202, média=0.50813, max=0.98718
#  Geração 100: min=0.03684, média=0.52485, max=0.99723
#  Geração 150: min=0.03096, média=0.55606, max=0.99985
#  Geração 200: min=0.01809, média=0.57782, max=0.99990
#  Geração 250: min=0.00246, média=0.63218, max=0.99999
#  Geração 300: min=0.00294, média=0.62225, max=1.00000
#  Geração 350: min=0.02334, média=0.64127, max=1.00000
#  Geração 400: min=0.03670, média=0.63885, max=1.00000
#  Geração 450: min=0.05227, média=0.69612, max=1.00000
#  Geração 500: min=0.02148, média=0.66909, max=1.00000
# ✅ Finalizada Execução 9/32 — Melhor fitness: 1.00000
#
# 🧪 Iniciando Execução 10/32
#  Geração 001: min=0.02953, média=0.50225, max=0.90680
#  Geração 050: min=0.08063, média=0.52064, max=0.99028
#  Geração 100: min=0.05636, média=0.62984, max=0.99028
#  Geração 150: min=0.04652, média=0.64569, max=0.99028
#  Geração 200: min=0.05126, média=0.63766, max=0.99028
#  Geração 250: min=0.00284, média=0.64025, max=0.99028
#  Geração 300: min=0.02198, média=0.62559, max=0.99028
#  Geração 350: min=0.05787, média=0.61647, max=0.99028
#  Geração 400: min=0.01774, média=0.64417, max=0.99028
#  Geração 450: min=0.05651, média=0.64075, max=0.99028
#  Geração 500: min=0.00277, média=0.64786, max=0.99028
# ✅ Finalizada Execução 10/32 — Melhor fitness: 0.99028
#
# 🧪 Iniciando Execução 11/32
#  Geração 001: min=0.11571, média=0.49915, max=0.82140
#  Geração 050: min=0.00903, média=0.55870, max=0.99028
#  Geração 100: min=0.04217, média=0.64277, max=0.99028
#  Geração 150: min=0.02232, média=0.68705, max=0.99028
#  Geração 200: min=0.00356, média=0.65868, max=0.99028
#  Geração 250: min=0.02377, média=0.65481, max=0.99028
#  Geração 300: min=0.00626, média=0.62600, max=0.99028
#  Geração 350: min=0.04601, média=0.66689, max=0.99028
#  Geração 400: min=0.02151, média=0.66061, max=0.99028
#  Geração 450: min=0.04624, média=0.66338, max=0.99028
#  Geração 500: min=0.02186, média=0.67550, max=0.99028
# ✅ Finalizada Execução 11/32 — Melhor fitness: 0.99028
#
# 🧪 Iniciando Execução 12/32
#  Geração 001: min=0.14200, média=0.50666, max=0.90912
#  Geração 050: min=0.05640, média=0.51328, max=0.99026
#  Geração 100: min=0.03243, média=0.52994, max=0.99999
#  Geração 150: min=0.04697, média=0.59875, max=1.00000
#  Geração 200: min=0.04414, média=0.60238, max=1.00000
#  Geração 250: min=0.00313, média=0.61248, max=1.00000
#  Geração 300: min=0.00246, média=0.62826, max=1.00000
#  Geração 350: min=0.02368, média=0.61681, max=1.00000
#  Geração 400: min=0.02328, média=0.61613, max=1.00000
#  Geração 450: min=0.00277, média=0.65382, max=1.00000
#  Geração 500: min=0.00246, média=0.68043, max=1.00000
# ✅ Finalizada Execução 12/32 — Melhor fitness: 1.00000
#
# 🧪 Iniciando Execução 13/32
#  Geração 001: min=0.20338, média=0.50617, max=0.96122
#  Geração 050: min=0.04088, média=0.54595, max=0.99028
#  Geração 100: min=0.06151, média=0.57818, max=0.99028
#  Geração 150: min=0.04781, média=0.59483, max=0.99828
#  Geração 200: min=0.02504, média=0.64163, max=0.99981
#  Geração 250: min=0.00932, média=0.63809, max=0.99999
#  Geração 300: min=0.00249, média=0.65893, max=1.00000
#  Geração 350: min=0.00797, média=0.66167, max=1.00000
#  Geração 400: min=0.01515, média=0.64821, max=1.00000
#  Geração 450: min=0.02341, média=0.65312, max=1.00000
#  Geração 500: min=0.02568, média=0.66198, max=1.00000
# ✅ Finalizada Execução 13/32 — Melhor fitness: 1.00000
#
# 🧪 Iniciando Execução 14/32
#  Geração 001: min=0.03073, média=0.50395, max=0.96153
#  Geração 050: min=0.08313, média=0.51767, max=0.99028
#  Geração 100: min=0.02490, média=0.52589, max=0.99028
#  Geração 150: min=0.02196, média=0.63979, max=0.99028
#  Geração 200: min=0.03220, média=0.65157, max=0.99028
#  Geração 250: min=0.02222, média=0.62958, max=0.99028
#  Geração 300: min=0.02579, média=0.66358, max=0.99028
#  Geração 350: min=0.02192, média=0.65049, max=0.99028
#  Geração 400: min=0.02147, média=0.63919, max=0.99201
#  Geração 450: min=0.04310, média=0.66231, max=1.00000
#  Geração 500: min=0.00757, média=0.64652, max=1.00000
# ✅ Finalizada Execução 14/32 — Melhor fitness: 1.00000
#
# 🧪 Iniciando Execução 15/32
#  Geração 001: min=0.24105, média=0.50566, max=0.93379
#  Geração 050: min=0.03026, média=0.52405, max=0.99028
#  Geração 100: min=0.02233, média=0.59876, max=0.99028
#  Geração 150: min=0.02164, média=0.61070, max=0.99028
#  Geração 200: min=0.05638, média=0.58639, max=0.99028
#  Geração 250: min=0.01226, média=0.61515, max=0.99028
#  Geração 300: min=0.02719, média=0.66966, max=0.99028
#  Geração 350: min=0.02373, média=0.63183, max=0.99028
#  Geração 400: min=0.03856, média=0.62147, max=0.99028
#  Geração 450: min=0.04276, média=0.61420, max=0.99028
#  Geração 500: min=0.05815, média=0.64477, max=0.99028
# ✅ Finalizada Execução 15/32 — Melhor fitness: 0.99028
#
# 🧪 Iniciando Execução 16/32
#  Geração 001: min=0.28593, média=0.50389, max=0.87274
#  Geração 050: min=0.05749, média=0.51099, max=0.99028
#  Geração 100: min=0.00248, média=0.61980, max=0.99028
#  Geração 150: min=0.03095, média=0.64675, max=0.99028
#  Geração 200: min=0.03719, média=0.60733, max=0.99028
#  Geração 250: min=0.00254, média=0.62445, max=0.99028
#  Geração 300: min=0.04316, média=0.66913, max=0.99028
#  Geração 350: min=0.05737, média=0.61168, max=0.99028
#  Geração 400: min=0.00386, média=0.61778, max=0.99028
#  Geração 450: min=0.01183, média=0.65279, max=0.99028
#  Geração 500: min=0.02489, média=0.64883, max=0.99028
# ✅ Finalizada Execução 16/32 — Melhor fitness: 0.99028
#
# 🧪 Iniciando Execução 17/32
#  Geração 001: min=0.16711, média=0.50804, max=0.85092
#  Geração 050: min=0.09002, média=0.54484, max=0.99028
#  Geração 100: min=0.00583, média=0.64018, max=0.99028
#  Geração 150: min=0.01463, média=0.62194, max=0.99028
#  Geração 200: min=0.00952, média=0.62578, max=0.99028
#  Geração 250: min=0.01876, média=0.60749, max=0.99028
#  Geração 300: min=0.05666, média=0.62352, max=0.99028
#  Geração 350: min=0.02417, média=0.60877, max=0.99028
#  Geração 400: min=0.01205, média=0.61141, max=0.99028
#  Geração 450: min=0.00467, média=0.61018, max=0.99913
#  Geração 500: min=0.00708, média=0.64979, max=0.99940
# ✅ Finalizada Execução 17/32 — Melhor fitness: 0.99940
#
# 🧪 Iniciando Execução 18/32
#  Geração 001: min=0.05662, média=0.50015, max=0.91476
#  Geração 050: min=0.00720, média=0.50592, max=0.99028
#  Geração 100: min=0.00316, média=0.60743, max=0.99028
#  Geração 150: min=0.00350, média=0.60653, max=0.99028
#  Geração 200: min=0.01170, média=0.65680, max=0.99028
#  Geração 250: min=0.03310, média=0.65983, max=0.99028
#  Geração 300: min=0.03036, média=0.60583, max=0.99028
#  Geração 350: min=0.00322, média=0.63736, max=0.99028
#  Geração 400: min=0.04961, média=0.67397, max=0.99028
#  Geração 450: min=0.02692, média=0.63382, max=0.99028
#  Geração 500: min=0.02231, média=0.63524, max=0.99028
# ✅ Finalizada Execução 18/32 — Melhor fitness: 0.99028
#
# 🧪 Iniciando Execução 19/32
#  Geração 001: min=0.21702, média=0.50141, max=0.94278
#  Geração 050: min=0.00416, média=0.51450, max=0.99028
#  Geração 100: min=0.02259, média=0.50951, max=0.99028
#  Geração 150: min=0.02474, média=0.59230, max=0.99028
#  Geração 200: min=0.02409, média=0.61090, max=0.99028
#  Geração 250: min=0.00716, média=0.65532, max=0.99028
#  Geração 300: min=0.00519, média=0.66715, max=0.99028
#  Geração 350: min=0.00251, média=0.68975, max=0.99028
#  Geração 400: min=0.00325, média=0.65327, max=0.99028
#  Geração 450: min=0.02151, média=0.67511, max=0.99028
#  Geração 500: min=0.02302, média=0.63749, max=0.99028
# ✅ Finalizada Execução 19/32 — Melhor fitness: 0.99028
#
# 🧪 Iniciando Execução 20/32
#  Geração 001: min=0.03235, média=0.50193, max=0.92144
#  Geração 050: min=0.02238, média=0.52093, max=0.99024
#  Geração 100: min=0.03711, média=0.51677, max=0.99028
#  Geração 150: min=0.02964, média=0.63181, max=0.99028
#  Geração 200: min=0.02235, média=0.62687, max=0.99028
#  Geração 250: min=0.02780, média=0.67282, max=0.99028
#  Geração 300: min=0.02765, média=0.66782, max=0.99028
#  Geração 350: min=0.05591, média=0.65064, max=0.99028
#  Geração 400: min=0.01753, média=0.67875, max=0.99028
#  Geração 450: min=0.00246, média=0.64465, max=0.99991
#  Geração 500: min=0.02472, média=0.62676, max=0.99998
# ✅ Finalizada Execução 20/32 — Melhor fitness: 0.99998
#
# 🧪 Iniciando Execução 21/32
#  Geração 001: min=0.03659, média=0.50069, max=0.95389
#  Geração 050: min=0.06879, média=0.51168, max=0.97921
#  Geração 100: min=0.12229, média=0.52096, max=0.99028
#  Geração 150: min=0.05648, média=0.63345, max=0.99028
#  Geração 200: min=0.02848, média=0.66426, max=0.99028
#  Geração 250: min=0.00247, média=0.65736, max=0.99028
#  Geração 300: min=0.00324, média=0.65021, max=0.99028
#  Geração 350: min=0.02262, média=0.65620, max=0.99028
#  Geração 400: min=0.03785, média=0.62622, max=0.99028
#  Geração 450: min=0.00277, média=0.64644, max=0.99028
#  Geração 500: min=0.05656, média=0.60699, max=0.99028
# ✅ Finalizada Execução 21/32 — Melhor fitness: 0.99028
#
# 🧪 Iniciando Execução 22/32
#  Geração 001: min=0.06584, média=0.50291, max=0.94161
#  Geração 050: min=0.07929, média=0.50718, max=0.99028
#  Geração 100: min=0.00349, média=0.52979, max=0.99028
#  Geração 150: min=0.00263, média=0.60205, max=0.99999
#  Geração 200: min=0.00246, média=0.59544, max=1.00000
#  Geração 250: min=0.00251, média=0.65059, max=1.00000
#  Geração 300: min=0.02039, média=0.65347, max=1.00000
#  Geração 350: min=0.04143, média=0.65512, max=1.00000
#  Geração 400: min=0.03221, média=0.65265, max=1.00000
#  Geração 450: min=0.00315, média=0.64337, max=1.00000
#  Geração 500: min=0.00246, média=0.66637, max=1.00000
# ✅ Finalizada Execução 22/32 — Melhor fitness: 1.00000
#
# 🧪 Iniciando Execução 23/32
#  Geração 001: min=0.26817, média=0.50542, max=0.92162
#  Geração 050: min=0.00436, média=0.53652, max=0.99583
#  Geração 100: min=0.00482, média=0.62015, max=0.99999
#  Geração 150: min=0.02096, média=0.66301, max=1.00000
#  Geração 200: min=0.00259, média=0.66630, max=1.00000
#  Geração 250: min=0.01629, média=0.64560, max=1.00000
#  Geração 300: min=0.01006, média=0.69840, max=1.00000
#  Geração 350: min=0.02345, média=0.65848, max=1.00000
#  Geração 400: min=0.04195, média=0.65233, max=1.00000
#  Geração 450: min=0.00785, média=0.66334, max=1.00000
#  Geração 500: min=0.01991, média=0.65320, max=1.00000
# ✅ Finalizada Execução 23/32 — Melhor fitness: 1.00000
#
# 🧪 Iniciando Execução 24/32
#  Geração 001: min=0.24029, média=0.50568, max=0.91998
#  Geração 050: min=0.00288, média=0.51770, max=0.99025
#  Geração 100: min=0.22910, média=0.51009, max=0.99028
#  Geração 150: min=0.01538, média=0.55057, max=0.99028
#  Geração 200: min=0.01223, média=0.61732, max=0.99028
#  Geração 250: min=0.00246, média=0.64457, max=0.99028
#  Geração 300: min=0.02174, média=0.64900, max=0.99028
#  Geração 350: min=0.05720, média=0.62364, max=0.99028
#  Geração 400: min=0.01467, média=0.65389, max=0.99028
#  Geração 450: min=0.02435, média=0.63875, max=0.99028
#  Geração 500: min=0.00483, média=0.68776, max=0.99028
# ✅ Finalizada Execução 24/32 — Melhor fitness: 0.99028
#
# 🧪 Iniciando Execução 25/32
#  Geração 001: min=0.29675, média=0.50710, max=0.98679
#  Geração 050: min=0.07807, média=0.51881, max=0.99999
#  Geração 100: min=0.01348, média=0.55347, max=1.00000
#  Geração 150: min=0.00337, média=0.60006, max=1.00000
#  Geração 200: min=0.00412, média=0.57816, max=1.00000
#  Geração 250: min=0.00459, média=0.57145, max=1.00000
#  Geração 300: min=0.00286, média=0.59196, max=1.00000
#  Geração 350: min=0.02181, média=0.66617, max=1.00000
#  Geração 400: min=0.00250, média=0.66948, max=1.00000
#  Geração 450: min=0.00253, média=0.67360, max=1.00000
#  Geração 500: min=0.00250, média=0.61995, max=1.00000
# ✅ Finalizada Execução 25/32 — Melhor fitness: 1.00000
#
# 🧪 Iniciando Execução 26/32
#  Geração 001: min=0.13370, média=0.51024, max=0.96189
#  Geração 050: min=0.00294, média=0.51484, max=0.99801
#  Geração 100: min=0.00369, média=0.62068, max=0.99981
#  Geração 150: min=0.00256, média=0.60836, max=1.00000
#  Geração 200: min=0.02563, média=0.64029, max=1.00000
#  Geração 250: min=0.03815, média=0.62411, max=1.00000
#  Geração 300: min=0.02248, média=0.61557, max=1.00000
#  Geração 350: min=0.03764, média=0.64740, max=1.00000
#  Geração 400: min=0.00638, média=0.63997, max=1.00000
#  Geração 450: min=0.00612, média=0.63856, max=1.00000
#  Geração 500: min=0.02004, média=0.61874, max=1.00000
# ✅ Finalizada Execução 26/32 — Melhor fitness: 1.00000
#
# 🧪 Iniciando Execução 27/32
#  Geração 001: min=0.11283, média=0.50585, max=0.92564
#  Geração 050: min=0.00287, média=0.57409, max=0.99079
#  Geração 100: min=0.01507, média=0.66013, max=0.99993
#  Geração 150: min=0.00303, média=0.66584, max=0.99996
#  Geração 200: min=0.04073, média=0.65303, max=0.99999
#  Geração 250: min=0.00444, média=0.65546, max=1.00000
#  Geração 300: min=0.00250, média=0.66870, max=1.00000
#  Geração 350: min=0.02201, média=0.68916, max=1.00000
#  Geração 400: min=0.00247, média=0.62736, max=1.00000
#  Geração 450: min=0.01458, média=0.62825, max=1.00000
#  Geração 500: min=0.00862, média=0.62335, max=1.00000
# ✅ Finalizada Execução 27/32 — Melhor fitness: 1.00000
#
# 🧪 Iniciando Execução 28/32
#  Geração 001: min=0.16467, média=0.50899, max=0.92125
#  Geração 050: min=0.09438, média=0.51156, max=0.99028
#  Geração 100: min=0.01463, média=0.54824, max=0.99832
#  Geração 150: min=0.00973, média=0.64967, max=0.99966
#  Geração 200: min=0.00266, média=0.66976, max=0.99983
#  Geração 250: min=0.02147, média=0.62392, max=0.99985
#  Geração 300: min=0.01385, média=0.66238, max=0.99985
#  Geração 350: min=0.00414, média=0.64546, max=0.99989
#  Geração 400: min=0.01035, média=0.60511, max=0.99995
#  Geração 450: min=0.00248, média=0.66595, max=1.00000
#  Geração 500: min=0.03749, média=0.66270, max=1.00000
# ✅ Finalizada Execução 28/32 — Melhor fitness: 1.00000
#
# 🧪 Iniciando Execução 29/32
#  Geração 001: min=0.20341, média=0.49939, max=0.96458
#  Geração 050: min=0.03227, média=0.55191, max=0.99028
#  Geração 100: min=0.02207, média=0.58798, max=0.99028
#  Geração 150: min=0.00809, média=0.65575, max=0.99028
#  Geração 200: min=0.02514, média=0.63026, max=0.99028
#  Geração 250: min=0.04063, média=0.59967, max=0.99028
#  Geração 300: min=0.02312, média=0.62187, max=0.99028
#  Geração 350: min=0.02148, média=0.61750, max=0.99028
#  Geração 400: min=0.02173, média=0.63108, max=0.99028
#  Geração 450: min=0.01466, média=0.61788, max=0.99169
#  Geração 500: min=0.05866, média=0.64856, max=0.99998
# ✅ Finalizada Execução 29/32 — Melhor fitness: 0.99998
#
# 🧪 Iniciando Execução 30/32
#  Geração 001: min=0.24906, média=0.50022, max=0.81428
#  Geração 050: min=0.00264, média=0.51342, max=0.99028
#  Geração 100: min=0.02719, média=0.51541, max=0.99028
#  Geração 150: min=0.02159, média=0.61502, max=0.99028
#  Geração 200: min=0.00589, média=0.67243, max=0.99028
#  Geração 250: min=0.02395, média=0.65856, max=0.99028
#  Geração 300: min=0.02421, média=0.66093, max=0.99028
#  Geração 350: min=0.00569, média=0.62215, max=0.99028
#  Geração 400: min=0.00382, média=0.63173, max=0.99028
#  Geração 450: min=0.02359, média=0.63725, max=0.99028
#  Geração 500: min=0.02147, média=0.65174, max=0.99028
# ✅ Finalizada Execução 30/32 — Melhor fitness: 0.99028
#
# 🧪 Iniciando Execução 31/32
#  Geração 001: min=0.21385, média=0.50597, max=0.89573
#  Geração 050: min=0.15100, média=0.51649, max=0.99028
#  Geração 100: min=0.01258, média=0.56817, max=0.99028
#  Geração 150: min=0.00267, média=0.64965, max=0.99028
#  Geração 200: min=0.02227, média=0.63783, max=0.99028
#  Geração 250: min=0.03127, média=0.63430, max=0.99300
#  Geração 300: min=0.02237, média=0.66567, max=0.99994
#  Geração 350: min=0.01874, média=0.65845, max=0.99996
#  Geração 400: min=0.00738, média=0.63757, max=1.00000
#  Geração 450: min=0.00372, média=0.63725, max=1.00000
#  Geração 500: min=0.00302, média=0.68697, max=1.00000
# ✅ Finalizada Execução 31/32 — Melhor fitness: 1.00000
#
# 🧪 Iniciando Execução 32/32
#  Geração 001: min=0.11470, média=0.50372, max=0.94529
#  Geração 050: min=0.03551, média=0.51870, max=0.99028
#  Geração 100: min=0.00549, média=0.56101, max=0.99746
#  Geração 150: min=0.03192, média=0.55016, max=1.00000
#  Geração 200: min=0.02270, média=0.60710, max=1.00000
#  Geração 250: min=0.00246, média=0.63869, max=1.00000
#  Geração 300: min=0.00283, média=0.65159, max=1.00000
#  Geração 350: min=0.03802, média=0.60026, max=1.00000
#  Geração 400: min=0.01328, média=0.65374, max=1.00000
#  Geração 450: min=0.01181, média=0.63148, max=1.00000
#  Geração 500: min=0.00776, média=0.67641, max=1.00000
# ✅ Finalizada Execução 32/32 — Melhor fitness: 1.00000

# %% [markdown]
# 3. GIF da trajetória do melhor indivíduo

# %%
# Geração do grid para heatmap
X, Y = np.meshgrid(np.linspace(x_min, x_max, 400), np.linspace(y_min, y_max, 400))
Z = shaffer_f6(X, Y)

# Salvar frames com o melhor indivíduo
frames = []
ga_best = best_attempt["ga"]

max_idx = min(len(ga_best.best_solutions), N_GEN)

for gen in range(0, max_idx, SAVE_INTERVAL):
    sol = ga_best.best_solutions[gen]
    x, y = decode_solution(sol)

    plt.figure(figsize=(6,5))
    plt.contourf(X, Y, Z, levels=100, cmap='viridis')
    plt.colorbar(label='F6(x, y)')
    plt.plot(x, y, 'ro')
    plt.title(f"Geração {gen}")
    plt.xlabel('x')
    plt.ylabel('y')

    fname = f"heatmap_frames/frame_{gen:03}.png"
    plt.savefig(fname)
    plt.close()
    frames.append(fname)

# Diretório com os frames
frames_dir = "heatmap_frames"

# Ordenar e filtrar os arquivos .png
frame_files = sorted([f for f in os.listdir(frames_dir) if f.endswith(".png")])

# Garantir que há pelo menos um frame
assert frame_files, "Nenhum frame encontrado em 'heatmap_frames/'."

# Ler o primeiro frame para obter dimensões
frame_path = os.path.join(frames_dir, frame_files[0])
frame = cv2.imread(frame_path)
height, width, _ = frame.shape

# Criar VideoWriter com codec MP4
out = cv2.VideoWriter("evolucao_melhor_individuo.mp4", cv2.VideoWriter_fourcc(*'mp4v'), 5, (width, height))

# Escrever cada frame no vídeo
for fname in frame_files:
    img = cv2.imread(os.path.join(frames_dir, fname))
    out.write(img)

out.release()
print("🎬 Vídeo 'evolucao_melhor_individuo.mp4' criado com sucesso.")
# Out:
# 🎬 Vídeo 'evolucao_melhor_individuo.mp4' criado com sucesso.

# %% [markdown]
# 4. Visualização da população em binário

# %%
pop_matrix = np.array(ga_best.population)

plt.figure(figsize=(12,6))
sns.heatmap(pop_matrix, cmap="gray_r", cbar=False)
plt.title("População final (representação binária)")
plt.xlabel("Bits do gene")
plt.ylabel("Indivíduo")
plt.tight_layout()
plt.savefig("population_genes/final_population_binary.png")
plt.close()

# %% [markdown]
# 5. Gráfico de convergência com média e desvio padrão

# %%
padded_runs = []
for run in all_runs_fitness:
    run = np.array(run)
    if len(run) < N_GEN:
        padded = np.pad(run, (0, N_GEN - len(run)), constant_values=run[-1])
    else:
        padded = run[:N_GEN]
    padded_runs.append(padded)

all_runs_fitness = np.array(padded_runs)

mean_fitness = np.mean(all_runs_fitness, axis=0)
std_fitness = np.std(all_runs_fitness, axis=0)

plt.figure(figsize=(10,6))
plt.plot(mean_fitness, label='Média da Fitness', color='blue')
plt.fill_between(range(N_GEN), mean_fitness - std_fitness, mean_fitness + std_fitness, alpha=0.3, color='gray', label='Desvio Padrão')
plt.xlabel('Geração')
plt.ylabel('Fitness')
plt.title('Convergência Média da Fitness em 32 Execuções')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.savefig("convergencia_fitness.png")
plt.close()

# %% [markdown]
# Trajetória sobre o mapa de calor da função

# %%
import plotly.graph_objects as go

# Geração da malha
x_vals = np.linspace(x_min, x_max, 200)
y_vals = np.linspace(y_min, y_max, 200)
X, Y = np.meshgrid(x_vals, y_vals)
Z = shaffer_f6(X, Y)

# Preparar coordenadas do melhor indivíduo a cada 10 gerações
traj_x, traj_y = [], []
for gen in range(0, N_GEN, SAVE_INTERVAL):
    sol = ga_best.best_solutions[gen]
    x, y = decode_solution(sol)
    traj_x.append(x)
    traj_y.append(y)

# Criar figura Plotly
fig = go.Figure()

# Heatmap de fundo
fig.add_trace(go.Heatmap(
    z=Z,
    x=x_vals,
    y=y_vals,
    colorscale='Viridis',
    colorbar=dict(title="F6(x,y)"),
    zsmooth="best"
))

# Linha da trajetória
fig.add_trace(go.Scatter(
    x=traj_x,
    y=traj_y,
    mode='markers+lines',
    marker=dict(color='red', size=8),
    name="Melhor indivíduo"
))

fig.update_layout(
    title="Evolução do Melhor Indivíduo na Função F6",
    xaxis_title="x",
    yaxis_title="y",
    width=800,
    height=700
)

fig.write_html("interativo_trajetoria_f6.html")
fig.show()
